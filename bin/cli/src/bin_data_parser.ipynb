# %%
import binascii

voters_n = 4
path_suffix = '../../../cmake-build-release/bin/cli/'
vi_pathes = [f'{path_suffix}verification_input_chunked{i}.bin' for i in range(voters_n)]
proof_pathes = [f'{path_suffix}proof{i}.bin' for i in range(voters_n)]
provkey_pathes = [f'{path_suffix}proving_key{i}.bin' for i in range(voters_n)]
vkey_pathes = [f'{path_suffix}verification_key{i}.bin' for i in range(voters_n)]
pubkey_pathes = [f'{path_suffix}public_key{i}.bin' for i in range(voters_n)]
ct_pathes = [f'{path_suffix}cipher_text{i}.bin' for i in range(voters_n)]
eid_pathes = [f'{path_suffix}eid{i}.bin' for i in range(voters_n)]
sn_pathes = [f'{path_suffix}sn{i}.bin' for i in range(voters_n)]
rt_pathes = [f'{path_suffix}rt{i}.bin' for i in range(voters_n)]

admin_addr = '0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4'
admin_lscs_name = 'voting_admin'

voters_lscs_addreses = []
voters_lscs_addreses.append('0:fb46eadacbd1d3454c33ee49226e5a6bab8987a67a8136e8b90113a9f843b229')
voters_lscs_addreses.append('0:f2fb12e27655be80dce83e47e2a6a29c32d0b79bf5c308213634fb76168f301c')
voters_lscs_addreses.append('0:2a5f6502a06266af4e4b4c243c41e5779eda91bbd0308a79903ef0ac4c8e1390')
voters_lscs_addreses.append('0:f486b67b7d1cb23a97f53bbd9e3ff8f1f2633ab3e7c16d113ce4cc03c22ebf38')
voter_lscs_name = 'voting_voter'

# %%
vi_n = []
for vi_path in vi_pathes:

    with open(vi_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        hexdata_str = '01' + hexdata.decode("ascii")
        vi_n.append(hexdata_str)
#         print(hexdata.decode("ascii"))
    
    print()
    print()

# print(len(vi_n[0])/2)
# print(len(proof_n[0] + vkey_n[0] + pubkey_n[0] + ct_n[0] + eid_n[0] + sn_n[0] + rt_n[0]))
# print(vi_n[0] == proof_n[0] + vkey_n[0] + pubkey_n[0] + ct_n[0] + eid_n[0] + sn_n[0] + rt_n[0])

# %%
eid_n = []
for eid_path in eid_pathes:

    with open(eid_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        eid_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()

# %%
sn_n = []
for sn_path in sn_pathes:

    with open(sn_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        sn_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()

# %%
rt_n = []
for rt_path in rt_pathes:

    with open(rt_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        rt_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
        
    
    print()
    print()

# %%
proof_n = []
for proof_path in proof_pathes:

    with open(proof_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        proof_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()
print(proof_n[0])
# Out:
# 

# %%
vkey_n = []
for vkey_path in vkey_pathes:

    with open(vkey_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        vkey_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()

assert vkey_n[0] == vkey_n[1]

# %%
provkey_n = []
for provkey_path in provkey_pathes:

    with open(provkey_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        provkey_n.append(hexdata.decode("ascii"))
        print(hexdata.decode("ascii"))
    
    print()
    print()

assert provkey_n[0] == provkey_n[1]
assert provkey_n[0] == provkey_n[2]
assert provkey_n[0] == provkey_n[3]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-224-d6134c95e115> in <module>
#       2 for provkey_path in provkey_pathes:
#       3
# ----> 4     with open(provkey_path, 'rb') as f:
#       5         hexdata = binascii.hexlify(f.read())
#       6         provkey_n.append(hexdata.decode("ascii"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../cmake-build-release/bin/cli/proving_key0.bin'

# %%
pubkey_n = []
for pubkey_path in pubkey_pathes:

    with open(pubkey_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        pubkey_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()

assert pubkey_n[0] == pubkey_n[1]
assert pubkey_n[0] == pubkey_n[2]
assert pubkey_n[0] == pubkey_n[3]

# %%
ct_n = []
for ct_path in ct_pathes:

    with open(ct_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        ct_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()
print(ct_n[0])
# Out:
# ...

# %%
def print_update_ballot_cmd(idx, addr, lscs_name, eid, sn, proof_rerand, ct_rerand):
    new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"{eid}", "sn":"{sn}", "proof_rerand":"{proof_rerand}", "ct_rerand":"{ct_rerand}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
    print(new_cmd)


def print_commit_ballot_cmd(idx, addr, lscs_name, ct_begin, eid_begin, sn_begin, sn_end):
    new_cmd = f'tonos-cli call {addr} commit_ballot \'{{"ct_begin":{ct_begin},"eid_begin":{eid_begin},"sn_begin":{sn_begin},"sn_end":{sn_end} }}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
    print(new_cmd)


def print_update_ballot_cmd_step(idx, step, addr, lscs_name, eid, sn, proof_rerand, ct_rerand):
    for i in range(0, len(eid), step):
        new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"{eid[i: i + step]}", "sn":"", "proof_rerand":"", "ct_rerand":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

    for i in range(0, len(sn), step):
        new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"", "sn":"{sn[i: i + step]}", "proof_rerand":"", "ct_rerand":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

    for i in range(0, len(proof_rerand), step):
        new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"", "sn":"", "proof_rerand":"{proof_rerand[i: i + step]}", "ct_rerand":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

    for i in range(0, len(ct_rerand), step):
        new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"", "sn":"", "proof_rerand":"", "ct_rerand":"{ct_rerand[i: i + step]}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()


def print_update_session_data_cmd_step(idx, step, addr, lscs_name, crs_vk, pk_eid, rt):
    for i in range(0, len(crs_vk), step):
        new_cmd = f'tonos-cli call {addr} update_session_data \'{{"crs_vk":"{crs_vk[i: i + step]}", "pk_eid":"", "rt":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

    for i in range(0, len(pk_eid), step):
        new_cmd = f'tonos-cli call {addr} update_session_data \'{{"crs_vk":"", "pk_eid":"{pk_eid[i: i + step]}", "rt":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

    for i in range(0, len(rt), step):
        new_cmd = f'tonos-cli call {addr} update_session_data \'{{"crs_vk":"", "pk_eid":"", "rt":"{rt[i: i + step]}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()
        
        
def print_construct_admin_cmd(lscs_name, pk, vk):
    new_cmd = f'tonos-cli deploy --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json {lscs_name}.tvc \'{{"pk":"{pk}", "vk":"{vk}"}}\'\n\n'
    print(new_cmd)   

    
def print_construct_admin_cmd_step(step, addr, lscs_name, pk, vk):
    new_cmd = f'tonos-cli deploy --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json {lscs_name}.tvc \'{{}}\'\n\n'
    print(new_cmd)   
    
    for i in range(0, len(pk), step):
        new_cmd = f'tonos-cli call {addr} update_crs \'{{"pk":"{pk[i: i + step]}", "vk":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json\n\n'
        print(new_cmd)
        print()
    
    for i in range(0, len(vk), step):
        new_cmd = f'tonos-cli call {addr} update_crs \'{{"pk":"", "vk":"{vk[i: i + step]}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json\n\n'
        print(new_cmd)
        print()


def print_construct_voter_cmd(idx, lscs_name, pk, admin_addr):
    new_cmd = f'tonos-cli deploy --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json {lscs_name}.tvc \'{{"pk":"{pk}", "admin":"{admin_addr}"}}\'\n\n'
    print(new_cmd)  
    
    
def print_giver_cmd(addr):
    new_cmd = f'tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction \'{{"dest":"{addr}","value":"100000000000","bounce":false}}\' --abi GiverV2.abi.json --sign GiverV2.keys.json\n\n'
    print(new_cmd)  


def print_init_voting(admin_addr, lscs_name, eid, pk_eid, vk_eid, voters_addr, rt):
    addresses = '[' + ','.join(f'"{addr}"' for addr in voters_addr) + ']'
    new_cmd = f'tonos-cli call {admin_addr} init_voting_session \'{{"eid":"{eid}","pk_eid":"{pk_eid}","vk_eid":"{vk_eid}","voters_addresses":{addresses},"rt":"{rt}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json\n\n'
    print(new_cmd)

def print_update_vi_cmd_step(idx, step, addr, lscs_name, vi):
    for i in range(0, len(vi), step):
        new_cmd = f'tonos-cli call {addr} update_ballot \'{{"vi":"{vi[i: i + step]}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

# %%
for i in range(voters_n):
    print_update_ballot_cmd(i, voters_lscs_addreses[i], voter_lscs_name, eid_n[i], sn_n[i], proof_n[i], ct_n[i])
    print()
    print()
# Out:
# tonos-cli call 0:8df231712695ec0b1eebf5a3512e96255b8790b5c7fe2b61661bb1be3b43a350 update_ballot '{"eid":"...", "sn":"...", "proof_rerand":"", "ct_rerand":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
#
# tonos-cli call 0:7a0f3f50cc8261e58ed9151a9672225c6a7c3422ec79bdc64e60701d0b8e6358 update_ballot '{"eid":"...", "sn":"...", "proof_rerand":"", "ct_rerand":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter1.keys.json
#
#
#
#
# tonos-cli call 0:5cab0604f0ed01023c71fb26ccec9172dd30928822daa5a07e7101df2269a06b update_ballot '{"eid":"...", "sn":"...", "proof_rerand":"", "ct_rerand":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter2.keys.json
#
#
#
#
# tonos-cli call 0:61134a18a3692a34b0323a16fadfed95307bfdd7d0fe2d9d85c3ffde870546a5 update_ballot '{"eid":"...", "sn":"...", "proof_rerand":"", "ct_rerand":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter3.keys.json

# %%
for i in range(voters_n):
    ct_offset = 1 + len(proof_n[i]) // 2 + len(vkey_n[i]) // 2 + len(pubkey_n[i]) // 2
    eid_offset = ct_offset + len(ct_n[i]) // 2
    sn_offset = eid_offset + len(eid_n[i]) // 2
    sn_end = sn_offset + len(sn_n[i]) // 2
    
    
    print_commit_ballot_cmd(i, voters_lscs_addreses[i], voter_lscs_name, ct_offset, eid_offset, sn_offset, sn_end)
    print()
    print()
# Out:
# tonos-cli call 0:fb46eadacbd1d3454c33ee49226e5a6bab8987a67a8136e8b90113a9f843b229 commit_ballot '{"ct_begin":35273,"eid_begin":35713,"sn_begin":37769,"sn_end":45937 }' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
#
# tonos-cli call 0:f2fb12e27655be80dce83e47e2a6a29c32d0b79bf5c308213634fb76168f301c commit_ballot '{"ct_begin":35273,"eid_begin":35713,"sn_begin":37769,"sn_end":45937 }' --abi voting_voter.abi.json --sign keys/voting_voter1.keys.json
#
#
#
#
# tonos-cli call 0:2a5f6502a06266af4e4b4c243c41e5779eda91bbd0308a79903ef0ac4c8e1390 commit_ballot '{"ct_begin":35273,"eid_begin":35713,"sn_begin":37769,"sn_end":45937 }' --abi voting_voter.abi.json --sign keys/voting_voter2.keys.json
#
#
#
#
# tonos-cli call 0:f486b67b7d1cb23a97f53bbd9e3ff8f1f2633ab3e7c16d113ce4cc03c22ebf38 commit_ballot '{"ct_begin":35273,"eid_begin":35713,"sn_begin":37769,"sn_end":45937 }' --abi voting_voter.abi.json --sign keys/voting_voter3.keys.json

# %%
# print_construct_admin_cmd(admin_lscs_name, '000102030405', vkey_n[0])
print_construct_admin_cmd_step(30000, admin_addr, admin_lscs_name, '000102030405', vkey_n[0])
# Out:
# tonos-cli deploy --abi voting_admin.abi.json --sign keys/voting_admin.keys.json voting_admin.tvc '{}'
#
#
# tonos-cli call 0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4 update_crs '{"pk":"000102030405", "vk":""}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json
#
#
#
# tonos-cli call 0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4 update_crs '{"pk":"", "vk":"..."}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json
#
#
#
# tonos-cli call 0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4 update_crs '{"pk":"", "vk":"..."}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json
#
#
#
# tonos-cli call 0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4 update_crs '{"pk":"", "vk":"..."}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json

# %%
for i in range(voters_n):
    print_construct_voter_cmd(i, voter_lscs_name, '010203', admin_addr)
    print()
    print()
# Out:
# tonos-cli deploy --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json voting_voter.tvc '{"pk":"010203", "admin":"0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4"}'
#
#
#
#
# tonos-cli deploy --abi voting_voter.abi.json --sign keys/voting_voter1.keys.json voting_voter.tvc '{"pk":"010203", "admin":"0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4"}'
#
#
#
#
# tonos-cli deploy --abi voting_voter.abi.json --sign keys/voting_voter2.keys.json voting_voter.tvc '{"pk":"010203", "admin":"0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4"}'
#
#
#
#
# tonos-cli deploy --abi voting_voter.abi.json --sign keys/voting_voter3.keys.json voting_voter.tvc '{"pk":"010203", "admin":"0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4"}'

# %%
print_giver_cmd(admin_addr)

for i in range(voters_n):
    print_giver_cmd(voters_lscs_addreses[i])
    print()
    print()
# Out:
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json
#
#
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:fb46eadacbd1d3454c33ee49226e5a6bab8987a67a8136e8b90113a9f843b229","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json
#
#
#
#
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:f2fb12e27655be80dce83e47e2a6a29c32d0b79bf5c308213634fb76168f301c","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json
#
#
#
#
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:2a5f6502a06266af4e4b4c243c41e5779eda91bbd0308a79903ef0ac4c8e1390","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json
#
#
#
#
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:f486b67b7d1cb23a97f53bbd9e3ff8f1f2633ab3e7c16d113ce4cc03c22ebf38","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json

# %%
print_init_voting(admin_addr, admin_lscs_name, eid_n[0], pubkey_n[0], '0001020403', voters_lscs_addreses, rt_n[0])
# Out:
# tonos-cli call 0:45bd3e1e25a8c7c2bcbd4efaf95d7f885688d25f5b009b14410c5fb211eabbd4 init_voting_session '{"eid":"...","pk_eid":"...","vk_eid":"0001020403","voters_addresses":["0:fb46eadacbd1d3454c33ee49226e5a6bab8987a67a8136e8b90113a9f843b229","0:f2fb12e27655be80dce83e47e2a6a29c32d0b79bf5c308213634fb76168f301c","0:2a5f6502a06266af4e4b4c243c41e5779eda91bbd0308a79903ef0ac4c8e1390","0:f486b67b7d1cb23a97f53bbd9e3ff8f1f2633ab3e7c16d113ce4cc03c22ebf38"],"rt":"..."}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json

# %%
idx = 0
print_update_vi_cmd_step(idx, 30000, voters_lscs_addreses[idx], voter_lscs_name, vi_n[idx])
# Out:
# tonos-cli call 0:fb46eadacbd1d3454c33ee49226e5a6bab8987a67a8136e8b90113a9f843b229 update_ballot '{"vi":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:fb46eadacbd1d3454c33ee49226e5a6bab8987a67a8136e8b90113a9f843b229 update_ballot '{"vi":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:fb46eadacbd1d3454c33ee49226e5a6bab8987a67a8136e8b90113a9f843b229 update_ballot '{"vi":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:fb46eadacbd1d3454c33ee49226e5a6bab8987a67a8136e8b90113a9f843b229 update_ballot '{"vi":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json

# %%
idx = 0
print_update_session_data_cmd_step(idx, 30000, voters_lscs_addreses[idx], voter_lscs_name, vkey_n[idx], pubkey_n[idx], rt_n[idx])
# Out:
# tonos-cli call 0:8df231712695ec0b1eebf5a3512e96255b8790b5c7fe2b61661bb1be3b43a350 update_session_data '{"crs_vk":"...", "pk_eid":"", "rt":""}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:8df231712695ec0b1eebf5a3512e96255b8790b5c7fe2b61661bb1be3b43a350 update_session_data '{"crs_vk":"...", "pk_eid":"", "rt":""}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:8df231712695ec0b1eebf5a3512e96255b8790b5c7fe2b61661bb1be3b43a350 update_session_data '{"crs_vk":"...", "pk_eid":"", "rt":""}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:8df231712695ec0b1eebf5a3512e96255b8790b5c7fe2b61661bb1be3b43a350 update_session_data '{"crs_vk":"", "pk_eid":"...", "rt":""}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:8df231712695ec0b1eebf5a3512e96255b8790b5c7fe2b61661bb1be3b43a350 update_session_data '{"crs_vk":"", "pk_eid":"", "rt":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json

# %%
0xd359
# Out:
# 54105
