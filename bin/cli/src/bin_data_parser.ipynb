# %%
import binascii

voters_n = 4
path_suffix = '../../../cmake-build-release/bin/cli/'
vi_pathes = [f'{path_suffix}verification_input{i}.bin' for i in range(voters_n)]
proof_pathes = [f'{path_suffix}proof{i}.bin' for i in range(voters_n)]
provkey_pathes = [f'{path_suffix}proving_key{i}.bin' for i in range(voters_n)]
vkey_pathes = [f'{path_suffix}verification_key{i}.bin' for i in range(voters_n)]
pubkey_pathes = [f'{path_suffix}public_key{i}.bin' for i in range(voters_n)]
ct_pathes = [f'{path_suffix}cipher_text{i}.bin' for i in range(voters_n)]
eid_pathes = [f'{path_suffix}eid{i}.bin' for i in range(voters_n)]
sn_pathes = [f'{path_suffix}sn{i}.bin' for i in range(voters_n)]
rt_pathes = [f'{path_suffix}rt{i}.bin' for i in range(voters_n)]

admin_addr = '0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4'
admin_lscs_name = 'voting_admin'

voters_lscs_addreses = []
voters_lscs_addreses.append('0:0d924b584862fdcc26dd48948fc4867d8da60659fccd6675881d791567fddd36')
voters_lscs_addreses.append('0:48597767a76f749ce1bdc4ebe5ae8b085953df96d0326c5d25914461dfc3db1b')
voters_lscs_addreses.append('0:868177cbb04430c83d5f40a5192974ec537c399da0c94936d2b0d056cecddd04')
voters_lscs_addreses.append('0:8857f5e83d93682b02f36c354e1d352594fc5ac27d095ad782719992a3710b9e')
voter_lscs_name = 'voting_voter'

# %%
vi_n = []
for vi_path in vi_pathes:

    with open(vi_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        vi_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()

# print(len(vi_n[0])/2)
# print(len(proof_n[0] + vkey_n[0] + pubkey_n[0] + ct_n[0] + eid_n[0] + sn_n[0] + rt_n[0]))
# print(vi_n[0] == proof_n[0] + vkey_n[0] + pubkey_n[0] + ct_n[0] + eid_n[0] + sn_n[0] + rt_n[0])

# %%
eid_n = []
for eid_path in eid_pathes:

    with open(eid_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        eid_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()

# %%
sn_n = []
for sn_path in sn_pathes:

    with open(sn_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        sn_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()

# %%
rt_n = []
for rt_path in rt_pathes:

    with open(rt_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        rt_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
        
    
    print()
    print()

# %%
proof_n = []
for proof_path in proof_pathes:

    with open(proof_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        proof_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()
print(proof_n[0])
# Out:
# 

# %%
vkey_n = []
for vkey_path in vkey_pathes:

    with open(vkey_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        vkey_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()

assert vkey_n[0] == vkey_n[1]

# %%
provkey_n = []
for provkey_path in provkey_pathes:

    with open(provkey_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        provkey_n.append(hexdata.decode("ascii"))
        print(hexdata.decode("ascii"))
    
    print()
    print()

assert provkey_n[0] == provkey_n[1]
assert provkey_n[0] == provkey_n[2]
assert provkey_n[0] == provkey_n[3]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-138-d6134c95e115> in <module>
#       2 for provkey_path in provkey_pathes:
#       3
# ----> 4     with open(provkey_path, 'rb') as f:
#       5         hexdata = binascii.hexlify(f.read())
#       6         provkey_n.append(hexdata.decode("ascii"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../cmake-build-release/bin/cli/proving_key0.bin'

# %%
pubkey_n = []
for pubkey_path in pubkey_pathes:

    with open(pubkey_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        pubkey_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()

assert pubkey_n[0] == pubkey_n[1]
assert pubkey_n[0] == pubkey_n[2]
assert pubkey_n[0] == pubkey_n[3]

# %%
ct_n = []
for ct_path in ct_pathes:

    with open(ct_path, 'rb') as f:
        hexdata = binascii.hexlify(f.read())
        ct_n.append(hexdata.decode("ascii"))
#         print(hexdata.decode("ascii"))
    
    print()
    print()
print(ct_n[0])
# Out:
# ...

# %%
def print_update_ballot_cmd(idx, addr, lscs_name, eid, sn, proof_rerand, ct_rerand):
    new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"{eid}", "sn":"{sn}", "proof_rerand":"{proof_rerand}", "ct_rerand":"{ct_rerand}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
    print(new_cmd)


def print_commit_ballot_cmd(idx, addr, lscs_name):
    new_cmd = f'tonos-cli call {addr} commit_ballot \'{{}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
    print(new_cmd)


def print_update_ballot_cmd_step(idx, step, addr, lscs_name, eid, sn, proof_rerand, ct_rerand):
    for i in range(0, len(eid), step):
        new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"{eid[i: i + step]}", "sn":"", "proof_rerand":"", "ct_rerand":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

    for i in range(0, len(sn), step):
        new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"", "sn":"{sn[i: i + step]}", "proof_rerand":"", "ct_rerand":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

    for i in range(0, len(proof_rerand), step):
        new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"", "sn":"", "proof_rerand":"{proof_rerand[i: i + step]}", "ct_rerand":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

    for i in range(0, len(ct_rerand), step):
        new_cmd = f'tonos-cli call {addr} update_ballot \'{{"eid":"", "sn":"", "proof_rerand":"", "ct_rerand":"{ct_rerand[i: i + step]}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()


def print_construct_admin_cmd(lscs_name, pk, vk):
    new_cmd = f'tonos-cli deploy --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json {lscs_name}.tvc \'{{"pk":"{pk}", "vk":"{vk}"}}\'\n\n'
    print(new_cmd)   

    
def print_construct_admin_cmd_step(step, addr, lscs_name, pk, vk):
    new_cmd = f'tonos-cli deploy --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json {lscs_name}.tvc \'{{}}\'\n\n'
    print(new_cmd)   
    
    for i in range(0, len(pk), step):
        new_cmd = f'tonos-cli call {addr} update_crs \'{{"pk":"{pk[i: i + step]}", "vk":""}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json\n\n'
        print(new_cmd)
        print()
    
    for i in range(0, len(vk), step):
        new_cmd = f'tonos-cli call {addr} update_crs \'{{"pk":"", "vk":"{vk[i: i + step]}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json\n\n'
        print(new_cmd)
        print()


def print_construct_voter_cmd(idx, lscs_name, pk, admin_addr):
    new_cmd = f'tonos-cli deploy --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json {lscs_name}.tvc \'{{"pk":"{pk}", "admin":"{admin_addr}"}}\'\n\n'
    print(new_cmd)  
    
    
def print_giver_cmd(addr):
    new_cmd = f'tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction \'{{"dest":"{addr}","value":"100000000000","bounce":false}}\' --abi GiverV2.abi.json --sign GiverV2.keys.json\n\n'
    print(new_cmd)  


def print_init_voting(admin_addr, lscs_name, eid, pk_eid, vk_eid, voters_addr, rt):
    addresses = '[' + ','.join(f'"{addr}"' for addr in voters_addr) + ']'
    new_cmd = f'tonos-cli call {admin_addr} init_voting_session \'{{"eid":"{eid}","pk_eid":"{pk_eid}","vk_eid":"{vk_eid}","voters_addresses":{addresses},"rt":"{rt}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}.keys.json\n\n'
    print(new_cmd)

def print_update_vi_cmd_step(idx, step, addr, lscs_name, vi):
    for i in range(0, len(vi), step):
        new_cmd = f'tonos-cli call {addr} update_verification_input \'{{"vi":"{vi[i: i + step]}"}}\' --abi {lscs_name}.abi.json --sign keys/{lscs_name}{idx}.keys.json\n\n'
        print(new_cmd)
        print()

# %%
for i in range(voters_n):
    print_update_ballot_cmd(i, voters_lscs_addreses[i], voter_lscs_name, eid_n[i], sn_n[i], proof_n[i], ct_n[i])
    print()
    print()
# Out:
# tonos-cli call 0:0d924b584862fdcc26dd48948fc4867d8da60659fccd6675881d791567fddd36 update_ballot '{"eid":"...", "sn":"...", "proof_rerand":"", "ct_rerand":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
#
# tonos-cli call 0:48597767a76f749ce1bdc4ebe5ae8b085953df96d0326c5d25914461dfc3db1b update_ballot '{"eid":"...", "sn":"...", "proof_rerand":"", "ct_rerand":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter1.keys.json
#
#
#
#
# tonos-cli call 0:868177cbb04430c83d5f40a5192974ec537c399da0c94936d2b0d056cecddd04 update_ballot '{"eid":"...", "sn":"...", "proof_rerand":"", "ct_rerand":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter2.keys.json
#
#
#
#
# tonos-cli call 0:8857f5e83d93682b02f36c354e1d352594fc5ac27d095ad782719992a3710b9e update_ballot '{"eid":"...", "sn":"...", "proof_rerand":"", "ct_rerand":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter3.keys.json

# %%
for i in range(voters_n):
    print_commit_ballot_cmd(i, voters_lscs_addreses[i], voter_lscs_name)
    print()
    print()
# Out:
# tonos-cli call 0:0d924b584862fdcc26dd48948fc4867d8da60659fccd6675881d791567fddd36 commit_ballot '{}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
#
# tonos-cli call 0:48597767a76f749ce1bdc4ebe5ae8b085953df96d0326c5d25914461dfc3db1b commit_ballot '{}' --abi voting_voter.abi.json --sign keys/voting_voter1.keys.json
#
#
#
#
# tonos-cli call 0:868177cbb04430c83d5f40a5192974ec537c399da0c94936d2b0d056cecddd04 commit_ballot '{}' --abi voting_voter.abi.json --sign keys/voting_voter2.keys.json
#
#
#
#
# tonos-cli call 0:8857f5e83d93682b02f36c354e1d352594fc5ac27d095ad782719992a3710b9e commit_ballot '{}' --abi voting_voter.abi.json --sign keys/voting_voter3.keys.json

# %%
# print_construct_admin_cmd(admin_lscs_name, '000102030405', vkey_n[0])
print_construct_admin_cmd_step(30000, admin_addr, admin_lscs_name, '000102030405', vkey_n[0])
# Out:
# tonos-cli deploy --abi voting_admin.abi.json --sign keys/voting_admin.keys.json voting_admin.tvc '{}'
#
#
# tonos-cli call 0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4 update_crs '{"pk":"000102030405", "vk":""}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json
#
#
#
# tonos-cli call 0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4 update_crs '{"pk":"", "vk":"..."}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json
#
#
#
# tonos-cli call 0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4 update_crs '{"pk":"", "vk":"..."}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json
#
#
#
# tonos-cli call 0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4 update_crs '{"pk":"", "vk":"..."}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json

# %%
for i in range(voters_n):
    print_construct_voter_cmd(i, voter_lscs_name, '010203', admin_addr)
    print()
    print()
# Out:
# tonos-cli deploy --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json voting_voter.tvc '{"pk":"010203", "admin":"0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4"}'
#
#
#
#
# tonos-cli deploy --abi voting_voter.abi.json --sign keys/voting_voter1.keys.json voting_voter.tvc '{"pk":"010203", "admin":"0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4"}'
#
#
#
#
# tonos-cli deploy --abi voting_voter.abi.json --sign keys/voting_voter2.keys.json voting_voter.tvc '{"pk":"010203", "admin":"0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4"}'
#
#
#
#
# tonos-cli deploy --abi voting_voter.abi.json --sign keys/voting_voter3.keys.json voting_voter.tvc '{"pk":"010203", "admin":"0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4"}'

# %%
print_giver_cmd(admin_addr)

for i in range(voters_n):
    print_giver_cmd(voters_lscs_addreses[i])
    print()
    print()
# Out:
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json
#
#
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:0d924b584862fdcc26dd48948fc4867d8da60659fccd6675881d791567fddd36","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json
#
#
#
#
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:48597767a76f749ce1bdc4ebe5ae8b085953df96d0326c5d25914461dfc3db1b","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json
#
#
#
#
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:868177cbb04430c83d5f40a5192974ec537c399da0c94936d2b0d056cecddd04","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json
#
#
#
#
# tonos-cli call 0:ece57bcc6c530283becbbd8a3b24d3c5987cdddc3c8b7b33be6e4a6312490415 sendTransaction '{"dest":"0:8857f5e83d93682b02f36c354e1d352594fc5ac27d095ad782719992a3710b9e","value":"100000000000","bounce":false}' --abi GiverV2.abi.json --sign GiverV2.keys.json

# %%
print_init_voting(admin_addr, admin_lscs_name, eid_n[0], pubkey_n[0], '0001020403', voters_lscs_addreses, rt_n[0])
# Out:
# tonos-cli call 0:0e0962c56351475228802440c5a140515fca965dd00ec9236919bc2022c33cd4 init_voting_session '{"eid":"...","pk_eid":"...","vk_eid":"0001020403","voters_addresses":["0:8fb1dec1b1ae2aec11585efa91f62e62e29c6cbe0cc728d97f987b3b7ae33e1d","0:48597767a76f749ce1bdc4ebe5ae8b085953df96d0326c5d25914461dfc3db1b","0:868177cbb04430c83d5f40a5192974ec537c399da0c94936d2b0d056cecddd04","0:8857f5e83d93682b02f36c354e1d352594fc5ac27d095ad782719992a3710b9e"],"rt":"..."}' --abi voting_admin.abi.json --sign keys/voting_admin.keys.json

# %%
idx = 0
print_update_vi_cmd_step(idx, 30000, voters_lscs_addreses[idx], voter_lscs_name, vi_n[idx])
# Out:
# tonos-cli call 0:0d924b584862fdcc26dd48948fc4867d8da60659fccd6675881d791567fddd36 update_verification_input '{"vi":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:0d924b584862fdcc26dd48948fc4867d8da60659fccd6675881d791567fddd36 update_verification_input '{"vi":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:0d924b584862fdcc26dd48948fc4867d8da60659fccd6675881d791567fddd36 update_verification_input '{"vi":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
#
#
#
# tonos-cli call 0:0d924b584862fdcc26dd48948fc4867d8da60659fccd6675881d791567fddd36 update_verification_input '{"vi":"..."}' --abi voting_voter.abi.json --sign keys/voting_voter0.keys.json
